# %% [markdown]
# # My first notebook

# %%
import pandas as pd

# %%
number = 2

# %%
number + 3
# Out:
# 5

# %%
my_list = [2, 4, 6, 8]

# %%
my_series = pd.Series(my_list)

# %%
my_series.sum()
# Out:
# 20

# %%
my_series.max()
# Out:
# 8

# %%
my_series.min()
# Out:
# 2

# %%
my_series.mean()
# Out:
# 5.0

# %%
my_series.median()
# Out:
# 5.0

# %%
my_series.std()
# Out:
# 2.5819888974716112

# %%
my_series.describe()
# Out:
# count    4.000000
# mean     5.000000
# std      2.581989
# min      2.000000
# 25%      3.500000
# 50%      5.000000
# 75%      6.500000
# max      8.000000
# dtype: float64

# %%
props = pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")

# %%
props.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4            71  PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# ...

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %%
contribs = pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")

# %%
contribs.head()
# Out:
#    calaccess_committee_id                              committee_name  \
# 0                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 1                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 2                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 4                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
#
#    calaccess_filing_id date_received contributor_lastname  \
# 0              2083796    2016-09-18              BERGMAN
# 1              2083796    2016-09-18                KAHLE
# 2              2083796    2016-07-15             MCDEVITT
# 3              2083796    2016-08-10      WARREN-SAMARIPA
# 4              2083796    2016-07-26      WARREN-SAMARIPA
#
#   contributor_firstname contributor_city contributor_state contributor_zip  \
# 0              GRETCHEN    SPRING VALLEY                CA           91978
# ...

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
prop = props[props.prop_name == 'PROPOSITION 062- DEATH PENALTY. INITIATIVE STATUTE.']

# %%
prop
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 63  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 64  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 65  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 66  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 67  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 68  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 69  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
#
#     ccdc_prop_id                                          prop_name  \
# 63            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 64            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 65            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 66            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# ...

# %%
prop.head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 63  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 64  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 65  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 66  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 67  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
#
#     ccdc_prop_id                                          prop_name  \
# 63            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 64            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 65            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 66            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 67            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 63                445                 1380590
# ...

# %%
prop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 63 to 69
# Data columns (total 8 columns):
# ocd_prop_id               7 non-null object
# calaccess_prop_id         7 non-null int64
# ccdc_prop_id              7 non-null int64
# prop_name                 7 non-null object
# ccdc_committee_id         7 non-null int64
# calaccess_committee_id    7 non-null int64
# committee_name            7 non-null object
# committee_position        7 non-null object
# dtypes: int64(4), object(4)
# memory usage: 504.0+ bytes

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.2+ MB

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %%
merged = pd.merge(prop, contribs, on='calaccess_committee_id')

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34442 entries, 0 to 34441
# Data columns (total 20 columns):
# ocd_prop_id                     34442 non-null object
# calaccess_prop_id               34442 non-null int64
# ccdc_prop_id                    34442 non-null int64
# prop_name                       34442 non-null object
# ccdc_committee_id               34442 non-null int64
# calaccess_committee_id          34442 non-null int64
# committee_name_x                34442 non-null object
# committee_position              34442 non-null object
# committee_name_y                34442 non-null object
# calaccess_filing_id             34442 non-null int64
# date_received                   34442 non-null object
# contributor_lastname            34438 non-null object
# contributor_firstname           33920 non-null object
# contributor_city                34434 non-null object
# contributor_state               34432 non-null object
# ...

# %%
merged.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 1  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 2  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 3  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 4  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
#
#    ccdc_prop_id                                          prop_name  \
# 0            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 1            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 2            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 3            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 4            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                445                 1380590
# ...

# %%
merged.amount.sum()
# Out:
# 32836678.18

# %%
merged.committee_position.value_counts()
# Out:
# OPPOSE     29633
# SUPPORT     4809
# Name: committee_position, dtype: int64

# %%
support = merged[merged.committee_position == 'SUPPORT']

# %%
oppose = merged[merged.committee_position == 'OPPOSE']

# %%
oppose.amount.sum()
# Out:
# 16836069.809999999

# %%
support.amount.sum()
# Out:
# 16000608.370000001

# %%
support.amount.sum() / merged.amount.sum()
# Out:
# 0.48727853293472212

# %%
merged.sort_values('amount', ascending=False).head()
# Out:
#                                             ocd_prop_id  calaccess_prop_id  \
# 33745  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 33737  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 33746  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 33744  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 33742  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
#
#        ccdc_prop_id                                          prop_name  \
# 33745            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 33737            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 33746            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 33744            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 33742            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
#
#        ccdc_committee_id  calaccess_committee_id  \
# ...

# %%
support.sort_values('amount', ascending=False).head()
# Out:
#                                             ocd_prop_id  calaccess_prop_id  \
# 33745  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 33737  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 33746  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 33744  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 33742  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
#
#        ccdc_prop_id                                          prop_name  \
# 33745            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 33737            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 33746            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 33744            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 33742            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
#
#        ccdc_committee_id  calaccess_committee_id  \
# ...

# %%
oppose.sort_values('amount', ascending=False).head()
# Out:
#                                             ocd_prop_id  calaccess_prop_id  \
# 33246  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 33014  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 33734  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 33696  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
# 32739  ocd-contest/cad98dde-416b-4cb3-8565-c1e8079511b3            1381268
#
#        ccdc_prop_id                                          prop_name  \
# 33246            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 33014            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 33734            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 33696            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
# 32739            81  PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...
#
#        ccdc_committee_id  calaccess_committee_id  \
# ...

# %%
merged.groupby("committee_name_x").amount.sum().reset_index().sort_values('amount', ascending=False)
# Out:
#                                     committee_name_x        amount
# 1  CALIFORNIANS TO MEND, NOT END, THE DEATH PENAL...  8.387852e+06
# 0  CALIFORNIA CORRECTIONAL PEACE OFFICERS ASSOCIA...  8.343218e+06
# 6  YES ON 62, NO ON 66. REPLACE THE COSTLY, FAILE...  7.621678e+06
# 2       FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))  6.140000e+06
# 3  MILLION VOTER PROJECT ACTION FUND - YES ON 55,...  2.110000e+06
# 5                           VOLUNTEERS FOR YES ON 62  1.289300e+05
# 4  SAN FRANCISCO POLICE OFFICERS ASSOCIATION ISSU...  1.050000e+05

# %%
merged.groupby(["contributor_firstname", "contributor_lastname"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#       contributor_firstname contributor_lastname     amount
# 28389                THOMAS               STEYER  1750000.0
# 21807              NICHOLAS              MCKEOWN  1500000.0
# 23734                  REED             HASTINGS  1000000.0
# 17402               L. JOHN                DOERR   500000.0
# 22506                  PAUL               GRAHAM   500000.0
# 11190              HENRY T.         NICHOLAS III   400000.0
# 16159                 JULIE             MOTAMEDI   350000.0
# 24673           ROBERT ALAN              EUSTACE   175000.0
# 27959                 SUSAN                GROFF   160000.0
# 14166                  JOHN            O'FARRELL   100000.0
# 9610                  FRANK            QUATTRONE   100000.0
# 18585              M. QUINN              DELANEY   100000.0
# 24270            RICHARD J.              RIORDAN   100000.0
# 10931                 H. F.        BOECKMANN, II   100000.0
# 28444             THOMAS F.               STEYER   100000.0
# ...

# %%
contribs.contributor_occupation.value_counts()
# Out:
# CORRECTIONAL OFFICER             28617
# RETIRED                           3795
# UNEMPLOYED                        2630
# NOT EMPLOYED                      2500
# ATTORNEY                          1364
# ENGINEER                           537
# PROFESSOR                          393
# PHYSICIAN                          356
# TEACHER                            352
# OWNER                              305
# WRITER                             275
# CONSULTANT                         251
# SALES                              197
# MANAGER                            191
# SOFTWARE ENGINEER                  172
# DIRECTOR                           164
# PRESIDENT                          160
# CHIEF EXECUTIVE OFFICER            122
# PSYCHOLOGIST                       113
# HOMEMAKER                          108
# SCIENTIST                          105
# CONTRACTOR                         102
# ARTIST                              97
# REGISTERED NURSE                    93
# ...

# %%
prof = contribs[contribs.contributor_occupation == 'CORRECTIONAL OFFICER']

# %%
prof
# Out:
#        calaccess_committee_id  \
# 108                   1302403
# 109                   1302403
# 110                   1302403
# 111                   1302403
# 112                   1302403
# 113                   1302403
# 114                   1302403
# 115                   1302403
# 116                   1302403
# 117                   1302403
# 118                   1302403
# 119                   1302403
# 120                   1302403
# 121                   1302403
# 122                   1302403
# 123                   1302403
# 124                   1302403
# 125                   1302403
# 126                   1302403
# 127                   1302403
# 128                   1302403
# 129                   1302403
# 130                   1302403
# 131                   1302403
# 132                   1302403
# 133                   1302403
# 134                   1302403
# 135                   1302403
# 136                   1302403
# 137                   1302403
# ...

# %%
prof.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28617 entries, 108 to 48558
# Data columns (total 13 columns):
# calaccess_committee_id          28617 non-null int64
# committee_name                  28617 non-null object
# calaccess_filing_id             28617 non-null int64
# date_received                   28617 non-null object
# contributor_lastname            28617 non-null object
# contributor_firstname           28617 non-null object
# contributor_city                28617 non-null object
# contributor_state               28617 non-null object
# contributor_zip                 28617 non-null object
# contributor_employer            28617 non-null object
# contributor_occupation          28617 non-null object
# contributor_is_self_employed    28617 non-null bool
# amount                          28617 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 2.9+ MB

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34442 entries, 0 to 34441
# Data columns (total 20 columns):
# ocd_prop_id                     34442 non-null object
# calaccess_prop_id               34442 non-null int64
# ccdc_prop_id                    34442 non-null int64
# prop_name                       34442 non-null object
# ccdc_committee_id               34442 non-null int64
# calaccess_committee_id          34442 non-null int64
# committee_name_x                34442 non-null object
# committee_position              34442 non-null object
# committee_name_y                34442 non-null object
# calaccess_filing_id             34442 non-null int64
# date_received                   34442 non-null object
# contributor_lastname            34438 non-null object
# contributor_firstname           33920 non-null object
# contributor_city                34434 non-null object
# contributor_state               34432 non-null object
# ...

# %%
merged2 = pd.merge(prof, props, on='calaccess_committee_id')

# %%
merged2
# Out:
#        calaccess_committee_id  \
# 0                     1302403
# 1                     1302403
# 2                     1302403
# 3                     1302403
# 4                     1302403
# 5                     1302403
# 6                     1302403
# 7                     1302403
# 8                     1302403
# 9                     1302403
# 10                    1302403
# 11                    1302403
# 12                    1302403
# 13                    1302403
# 14                    1302403
# 15                    1302403
# 16                    1302403
# 17                    1302403
# 18                    1302403
# 19                    1302403
# 20                    1302403
# 21                    1302403
# 22                    1302403
# 23                    1302403
# 24                    1302403
# 25                    1302403
# 26                    1302403
# 27                    1302403
# 28                    1302403
# 29                    1302403
# ...

# %%
merged2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57229 entries, 0 to 57228
# Data columns (total 20 columns):
# calaccess_committee_id          57229 non-null int64
# committee_name_x                57229 non-null object
# calaccess_filing_id             57229 non-null int64
# date_received                   57229 non-null object
# contributor_lastname            57229 non-null object
# contributor_firstname           57229 non-null object
# contributor_city                57229 non-null object
# contributor_state               57229 non-null object
# contributor_zip                 57229 non-null object
# contributor_employer            57229 non-null object
# contributor_occupation          57229 non-null object
# contributor_is_self_employed    57229 non-null bool
# amount                          57229 non-null float64
# ocd_prop_id                     57229 non-null object
# calaccess_prop_id               57229 non-null int64
# ...

# %%
merged2.prop_name.value_counts()
# Out:
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.    28612
# PROPOSITION 062- DEATH PENALTY. INITIATIVE STATUTE.                28612
# PROPOSITION 063- FIREARMS. AMMUNITION SALES. INTIATIVE STATUTE.        5
# Name: prop_name, dtype: int64

# %%
oppose.contributor_occupation
# Out:
# 4105                            NaN
# 4106                            NaN
# 4107                            NaN
# 4108                            NaN
# 4109                            NaN
# 4110           CORRECTIONAL OFFICER
# 4111           CORRECTIONAL OFFICER
# 4112           CORRECTIONAL OFFICER
# 4113           CORRECTIONAL OFFICER
# 4114           CORRECTIONAL OFFICER
# 4115           CORRECTIONAL OFFICER
# 4116           CORRECTIONAL OFFICER
# 4117           CORRECTIONAL OFFICER
# 4118           CORRECTIONAL OFFICER
# 4119           CORRECTIONAL OFFICER
# 4120           CORRECTIONAL OFFICER
# 4121           CORRECTIONAL OFFICER
# 4122           CORRECTIONAL OFFICER
# 4123           CORRECTIONAL OFFICER
# 4124           CORRECTIONAL OFFICER
# 4125           CORRECTIONAL OFFICER
# 4126           CORRECTIONAL OFFICER
# 4127           CORRECTIONAL OFFICER
# 4128           CORRECTIONAL OFFICER
# 4129           CORRECTIONAL OFFICER
# 4130           CORRECTIONAL OFFICER
# ...

# %%
support.contributor_occupation.value_counts()
# Out:
# UNEMPLOYED                                                      1624
# ATTORNEY                                                         726
# RETIRED                                                          372
# PROFESSOR                                                        212
# NOT-EMPLOYED                                                      84
# PHYSICIAN                                                         71
# WRITER                                                            66
# TEACHER                                                           43
# PSYCHOTHERAPIST                                                   38
# PSYCHOLOGIST                                                      38
# SOCIAL WORKER                                                     33
# CONSULTANT                                                        25
# CHIEF EXECUTIVE OFFICER                                           25
# SALES                                                             24
# ...

# %%
oppose.contributor_occupation.value_counts()
# Out:
# CORRECTIONAL OFFICER                    28612
# RETIRED                                   118
# HOMEMAKER                                  42
# OWNER                                      28
# ATTORNEY                                   26
# PRESIDENT                                  20
# COMPUTER PROGRAMMER                        18
# DISTRICT ATTORNEY                          14
# ASSISTANT DISTRICT ATTORNEY                10
# PROSECUTOR                                 10
# EXECUTIVE                                   8
# FARMER                                      8
# INSURANCE BROKER                            8
# CONTRACTOR                                  8
# CHAIRMAN & CEO                              8
# TEMPORARY WORKER                            6
# CEO                                         6
# DEPUTY DISTRICT ATTORNEY                    6
# PROPERTY MANAGEMENT                         6
# CHIEF ASSISTANT DISTRICT ATTORNEY           6
# ...
